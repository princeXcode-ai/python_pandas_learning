# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# CREATING A DATA FRAME

# %%
import numpy as np
import pandas as pd

# %%
data ={
    'name':['jhon','anna','peter','linda'],
    'age': [28,30,32,23],
    'city':['new york','paris','berlin','london'],
    'salary':[65000,70000,62000,85000]
}
pd.DataFrame(data)
# Out:
#     name  age      city  salary
# 0   jhon   28  new york   65000
# 1   anna   30     paris   70000
# 2  peter   32    berlin   62000
# 3  linda   23    london   85000

# %%
data_list=[
    ['jhon',28,'newyork',65000],
    ['anna',30,'paris',70000],
    ['peter',32,'berlin',62000],
    ['linda',23,'london',85000]
]

# %%
df2=pd.DataFrame(data_list)
columns = ["name","age","city","salary"]
df2 =pd.DataFrame(data_list,columns = columns)

# %%
df2
# Out:
#     name  age     city  salary
# 0   jhon   28  newyork   65000
# 1   anna   30    paris   70000
# 2  peter   32   berlin   62000
# 3  linda   23   london   85000

# %% [markdown]
# SELECTING AND INDEXING OF COLUMNS

# %%
df2['name']
# Out:
# 0     jhon
# 1     anna
# 2    peter
# 3    linda
# Name: name, dtype: object

# %%
df2[['name','city']]
# Out:
#     name     city
# 0   jhon  newyork
# 1   anna    paris
# 2  peter   berlin
# 3  linda   london

# %% [markdown]
# CREATING A NEW COLUMN

# %%
df2["desination"] = ["doctor","Engineer","doctor","Engineer"]
df2
# Out:
#     name  age     city  salary desination
# 0   jhon   28  newyork   65000     doctor
# 1   anna   30    paris   70000   Engineer
# 2  peter   32   berlin   62000     doctor
# 3  linda   23   london   85000   Engineer

# %% [markdown]
# REMOVE COLUMN

# %%
df2.drop('desination',axis = 1)
# Out:
#     name  age     city  salary
# 0   jhon   28  newyork   65000
# 1   anna   30    paris   70000
# 2  peter   32   berlin   62000
# 3  linda   23   london   85000

# %%
df2.drop(0,axis = 0)
# Out:
#     name  age    city  salary desination
# 1   anna   30   paris   70000   Engineer
# 2  peter   32  berlin   62000     doctor
# 3  linda   23  london   85000   Engineer

# %% [markdown]
# selecting rows

# %%
df2.loc[[0,1]]
# Out:
#    name  age     city  salary desination
# 0  jhon   28  newyork   65000     doctor
# 1  anna   30    paris   70000   Engineer

# %% [markdown]
# selecting subset of rows and columns

# %%
df2
# Out:
#     name  age     city  salary desination
# 0   jhon   28  newyork   65000     doctor
# 1   anna   30    paris   70000   Engineer
# 2  peter   32   berlin   62000     doctor
# 3  linda   23   london   85000   Engineer

# %%
df2.loc[[0,1]][["city","salary"]]
# Out:
#       city  salary
# 0  newyork   65000
# 1    paris   70000

# %%
df2.loc[[2,3]][["name","age"]]
# Out:
#     name  age
# 2  peter   32
# 3  linda   23

# %% [markdown]
# condition selection

# %%
df2
# Out:
#     name  age     city  salary desination
# 0   jhon   28  newyork   65000     doctor
# 1   anna   30    paris   70000   Engineer
# 2  peter   32   berlin   62000     doctor
# 3  linda   23   london   85000   Engineer

# %%
#i only want to see those people whose age is above 30

# %%
df2[df2["age"]>30]
# Out:
#     name  age    city  salary desination
# 2  peter   32  berlin   62000     doctor

# %%
# i only want people whose age is above 30 and their city must be berlin

# %%
df2[(df2["age"]>30) & (df2["city"]=="berlin")]
# Out:
#     name  age    city  salary desination
# 2  peter   32  berlin   62000     doctor
